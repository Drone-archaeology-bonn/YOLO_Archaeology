# %%
import json
import os
import geojson
from PIL import Image
import shutil

# %% [markdown]
# # Preparation

# %%
max_x_tile = 217 
max_y_tile = 162 

# Format should always be "XXXX"
all_tiles = ["{:05d}".format(number) for number in range(max_x_tile*max_y_tile)]

global_min_x = 314084.5 #- 20
global_min_y = 5585151.5 + 35

image_width = 224
image_height = 224

#print(os.getcwd())
#print(os.listdir('40_40/GeoJSON'))

# %% [markdown]
# # Functions

# %%
def find_site_types(sitetype: str) -> int:
    '''
    Given a json, find the int_sitetype_limes (now int_sitety) and output a classifer as either 0, 1, or 2
    0: Bombentrichter
    1: Grabhügel
    2: Meilerpodium
    Input: str
    Output: int
    '''
    if sitetype == 'Bombentrichter':
        return 0
    elif sitetype == 'Grabhügel':
        return 1
    elif sitetype == 'Meilerpodium':
        return 2
    else:
        raise Exception("Did not find Bombentrichter, Grabhügel, or Meilerpodium")

# %%
def gen_x_y_points(feature: list):
    '''
    Takes a feature and returns a list of the x and y coordinates aswell as all points
    Input: list
    Output: list, list, and list
    '''
    points = feature['geometry']['coordinates'][0] 
    x = [p[0] for p in points]
    y = [p[1] for p in points]
    return x, y, points

# %%
def calc_width(x: list) -> float:
    '''
    Given a list of all x values, identifies the width of the feature
    Input: list
    Output: float
    '''
    width = max(x) - min(x)
    #print(width)
    norm_width = width/image_width
    
    return norm_width

# %%
def calc_height(y: list) -> float:
    '''
    Given a list of all y values, identifies the height of the feature
    Input: list
    Output: float
    '''
    height = max(y) - min(y)
    norm_height = height/image_height
    
    return norm_height

# %%
def find_parameters(feature: list) -> list:
    '''
    Takes a single feature, extracts the necessary information, and returns a list of paramters.
    The parameters are in the specified order:
    [class, x_center, y_center, width, height]
    Input: list
    Output: list
    '''
    parameters = []
    
    x, y, points = gen_x_y_points(feature)
    x_cen, y_cen = ( sum(x) / len(points), sum(y) / len(points))
    
    norm_x, norm_y = normalize_parameters(x_cen, y_cen)
    
    parameters.append(find_site_types(feature['properties']['int_sitety']))
    parameters.append(norm_x)
    parameters.append(norm_y)
    parameters.append(calc_width(x))
    parameters.append(calc_height(y))
    return parameters

# %%
def normalize_parameters(x: float, y: float):
    '''
    Takes x and y value and normalizes them
    Origin (0,0) is the upper left corner
    Input: float
    Output: float
    '''
    #global_min_x = 314084.5
    #global_min_y = 5585151.5 + 30

    #image_width = 1211
    #image_height = 907
    
    # 1 in the grid is equal to 1 pixel
    x = x - global_min_x
    y = global_min_y - y
    
    x = x%image_width
    y = y%image_height
    
    #y = 907 - y
    
    norm_x = x/image_width
    norm_y = y/image_height
    
    #print(x, y, norm_x, norm_y)
    
    return norm_x, norm_y
    
    
#normalize_parameters(319390.35907340754, 5578030.177083888) #192

# %% [markdown]
# # Get Parameters

# %%
print("Start extracting the parameters from the feature files")

base_src_path = "GeoJSON"
base_target_path = "Labels"

no_labels = 0
contains_labels = 0

for i in range(max_x_tile*max_y_tile):
    
    file_name_geo = all_tiles[i] + ".geojson"
    src_path = os.path.join(base_src_path, file_name_geo)
    
    # Define target location e.g.'40_40/GeoJSON/0001.txt'
    file_name_txt = all_tiles[i] + ".txt"
    target_path = os.path.join(base_target_path, file_name_txt)
    
    # Load all GeoJSON files that exist
    try:
        f = open(src_path)
        json_file = geojson.load(f)
        print(file_name_geo + "File found")
    
    except:
        print(file_name_geo + " does not exist")
    
    all_my_parameters = []

    # Get all needed parameters
    try:
        for j in range(len(json_file["features"])):
            all_my_parameters.append(find_parameters(json_file['features'][j]))   # Add for each feature the parameters that YOLOv5 needs
    
    except:
        print("Nothing detected in this image: " + file_name_geo)    
    
    
    # Test to see what features are in one image
    for j in range(len(all_my_parameters)):
        print(all_my_parameters[j])
    
    # Save each label in one line
    with open(target_path, 'w') as target_file:
        target_file.write('\n'.join(([' '.join(map(str,j)) for j in all_my_parameters])))
    
print("Done")
#print(no_labels, contains_labels)
# Out:
# Start extracting the parameters from the feature files
# 00000.geojson does not exist
# 00001.geojson does not exist
# 00002.geojson does not exist
# 00003.geojson does not exist
# 00004.geojson does not exist
# 00005.geojson does not exist
# 00006.geojson does not exist
# 00007.geojson does not exist
# 00008.geojson does not exist
# 00009.geojson does not exist
# 00010.geojson does not exist
# 00011.geojson does not exist
# 00012.geojson does not exist
# 00013.geojson does not exist
# 00014.geojson does not exist
# 00015.geojson does not exist
# 00016.geojson does not exist
# 00017.geojson does not exist
# 00018.geojson does not exist
# 00019.geojson does not exist
# 00020.geojson does not exist
# 00021.geojson does not exist
# 00022.geojson does not exist
# 00023.geojson does not exist
# 00024.geojson does not exist
# 00025.geojson does not exist
# 00026.geojson does not exist
# 00027.geojson does not exist
# 00028.geojson does not exist
# 00029.geojson does not exist
# 00030.geojson does not exist
# 00031.geojson does not exist
# 00032.geojson does not exist
# 00033.geojson does not exist
# 00034.geojson does not exist
# 00035.geojson does not exist
# 00036.geojson does not exist
# 00037.geojson does not exist
# 00038.geojson does not exist
# 00039.geojson does not exist
# 00040.geojson does not exist
# 00041.geojson does not exist
# 00042.geojson does not exist
# 00043.geojson does not exist
# 00044.geojson does not exist
# 00045.geojson does not exist
# 00046.geojson does not exist
# 00047.geojson does not exist
# 00048.geojson does not exist
# 00049.geojson does not exist
# 00050.geojson does not exist
# 00051.geojson does not exist
# 00052.geojson does not exist
# 00053.geojson does not exist
# 00054.geojson does not exist
# 00055.geojson does not exist
# 00056.geojson does not exist
# 00057.geojson does not exist
# 00058.geojson does not exist
# 00059.geojson does not exist
# 00060.geojson does not exist
# 00061.geojson does not exist
# 00062.geojson does not exist
# 00063.geojson does not exist
# 00064.geojson does not exist
# 00065.geojson does not exist
# 00066.geojson does not exist
# 00067.geojson does not exist
# 00068.geojson does not exist
# 00069.geojson does not exist
# 00070.geojson does not exist
# 00071.geojson does not exist
# 00072.geojson does not exist
# 00073.geojson does not exist
# 00074.geojson does not exist
# 00075.geojson does not exist
# 00076.geojson does not exist
# 00077.geojson does not exist
# 00078.geojson does not exist
# 00079.geojson does not exist
# 00080.geojson does not exist
# 00081.geojson does not exist
# 00082.geojson does not exist
# 00083.geojson does not exist
# 00084.geojson does not exist
# 00085.geojson does not exist
# 00204.geojsonFile found
# 00205.geojsonFile found
# 00206.geojsonFile found
# 00207.geojsonFile found
# 00208.geojsonFile found
# 00209.geojsonFile found
# 00210.geojsonFile found
# 00211.geojsonFile found
# 00212.geojsonFile found
# 00213.geojsonFile found
# 00214.geojsonFile found
# 00215.geojsonFile found
# 00216.geojsonFile found
# 00217.geojsonFile found
# 00218.geojsonFile found
# 00219.geojsonFile found
# 00220.geojsonFile found
# 00221.geojsonFile found
# 00222.geojsonFile found
# 00223.geojsonFile found
# 00224.geojsonFile found
# 00225.geojsonFile found
# 00226.geojsonFile found
# 00227.geojsonFile found
# 00228.geojsonFile found
# 00229.geojsonFile found
# 00230.geojsonFile found
# 00231.geojsonFile found
# 00232.geojsonFile found
# 00233.geojsonFile found
# 00234.geojsonFile found
# 00235.geojsonFile found
# 00236.geojsonFile found
# 00237.geojsonFile found
# 00238.geojsonFile found
# 00239.geojsonFile found
# 00240.geojsonFile found
# 00241.geojsonFile found
# 00242.geojsonFile found
# 00243.geojsonFile found
# 00244.geojsonFile found
# 00245.geojsonFile found
# 00246.geojsonFile found
# 00247.geojsonFile found
# 00248.geojsonFile found
# 00249.geojsonFile found
# 00250.geojsonFile found
# 00251.geojsonFile found
# 00252.geojsonFile found
# 00253.geojsonFile found
# 00254.geojsonFile found
# 00255.geojsonFile found
# 00256.geojsonFile found
# 00257.geojsonFile found
# 00258.geojsonFile found
# 00259.geojsonFile found
# 00260.geojsonFile found
# 00261.geojsonFile found
# 00262.geojsonFile found
# 00263.geojsonFile found
# 00264.geojsonFile found
# 00265.geojsonFile found
# 00266.geojsonFile found
# 00267.geojsonFile found
# 00268.geojsonFile found
# 00269.geojsonFile found
# 00270.geojsonFile found
# 00271.geojsonFile found
# 00272.geojsonFile found
# 00273.geojsonFile found
# 00274.geojsonFile found
# 00275.geojsonFile found
# 00276.geojsonFile found
# 00277.geojsonFile found
# 00278.geojsonFile found
# 00279.geojsonFile found
# 00280.geojsonFile found
# 00281.geojsonFile found
# 00282.geojsonFile found
# 00283.geojsonFile found
# 00284.geojsonFile found
# 00285.geojsonFile found
# 00286.geojsonFile found
# 00287.geojsonFile found
# 00288.geojsonFile found
# 00289.geojsonFile found
# 00290.geojsonFile found
# 00291.geojsonFile found
# 00292.geojsonFile found
# 00293.geojsonFile found
# 00294.geojsonFile found
# 00295.geojsonFile found
# 00296.geojsonFile found
# 00297.geojsonFile found
# 00298.geojsonFile found
# 00299.geojsonFile found
# 00300.geojsonFile found
# 00301.geojsonFile found
# 00302.geojsonFile found
# 00303.geojsonFile found
# 00304.geojsonFile found
# 00305.geojsonFile found
# 00306.geojsonFile found
# 00307.geojsonFile found
# 00308.geojsonFile found
# 00309.geojsonFile found
# 00310.geojsonFile found
# 00311.geojsonFile found
# 00312.geojsonFile found
# 00313.geojsonFile found
# 00314.geojsonFile found
# 00315.geojsonFile found
# [2, 0.9111397812173111, 0.039669841764927175, 0.09050568303557936, 0.07521150892716832]
# 00316.geojsonFile found
# [2, 0.911013219598057, 0.9855474905260573, 0.06783693750003295, 0.015297580356543352]
# 00317.geojsonFile found
# 00318.geojsonFile found
# 00319.geojsonFile found
# 00320.geojsonFile found
# [2, 0.8446804256317202, 0.9282616338002428, 0.07940124107127693, 0.079404232142094]
# 00321.geojsonFile found
# [2, 0.9913178314423671, 0.8106170428800397, 0.013708107142779877, 0.05716553571151702]
# 00322.geojsonFile found
# 00323.geojsonFile found
# 00324.geojson does not exist
# 00325.geojson does not exist
# 00326.geojson does not exist
# 00327.geojson does not exist
# 00328.geojson does not exist
# 00329.geojson does not exist
# 00330.geojson does not exist
# 00331.geojsonFile found
# 00332.geojsonFile found
# 00333.geojsonFile found
# 00334.geojsonFile found
# 00335.geojsonFile found
# 00336.geojsonFile found
# 00337.geojsonFile found
# 00338.geojsonFile found
# 00339.geojsonFile found
# 00340.geojsonFile found
# 00341.geojsonFile found
# 00342.geojsonFile found
# 00343.geojsonFile found
# 00344.geojsonFile found
# 00345.geojsonFile found
# 00346.geojsonFile found
# 00347.geojsonFile found
# 00348.geojsonFile found
# 00349.geojsonFile found
# 00350.geojsonFile found
# 00351.geojsonFile found
# 00352.geojsonFile found
# 00353.geojsonFile found
# 00354.geojsonFile found
# 00355.geojsonFile found
# 00356.geojsonFile found
# 00357.geojsonFile found
# 00358.geojsonFile found
# 00359.geojsonFile found
# 00360.geojsonFile found
# 00361.geojsonFile found
# 00362.geojsonFile found
# 00363.geojsonFile found
# 00364.geojsonFile found
# 00365.geojsonFile found
# 00366.geojsonFile found
# 00367.geojsonFile found
# 00368.geojsonFile found
# 00369.geojsonFile found
# 00370.geojsonFile found
# 00371.geojsonFile found
# 00372.geojsonFile found
# 00373.geojsonFile found
# 00374.geojsonFile found
# 00375.geojsonFile found
# 00376.geojsonFile found
# 00377.geojsonFile found
# 00378.geojsonFile found
# 00379.geojsonFile found
# 00380.geojsonFile found
# 00381.geojsonFile found
# 00382.geojsonFile found
# 00383.geojsonFile found
# 00384.geojsonFile found
# 00385.geojsonFile found
# 00386.geojsonFile found
# 00387.geojsonFile found
# 00388.geojsonFile found
# 00389.geojsonFile found
# 00390.geojsonFile found
# 00391.geojsonFile found
# 00392.geojsonFile found
# 00393.geojsonFile found
# 00394.geojsonFile found
# 00395.geojsonFile found
# 00396.geojsonFile found
# 00397.geojsonFile found
# 00398.geojsonFile found
# 00399.geojsonFile found
# 00400.geojsonFile found
# 00401.geojsonFile found
# 00402.geojsonFile found
# 00403.geojsonFile found
# 00404.geojsonFile found
# 00405.geojsonFile found
# 00406.geojsonFile found
# 00407.geojsonFile found
# 00408.geojsonFile found
# 00409.geojsonFile found
# 00410.geojsonFile found
# 00411.geojsonFile found
# 00412.geojsonFile found
# 00413.geojsonFile found
# 00414.geojsonFile found
# 00415.geojsonFile found
# 00416.geojsonFile found
# 00417.geojsonFile found
# 00418.geojsonFile found
# 00419.geojsonFile found
# 00420.geojsonFile found
# 00421.geojsonFile found
# 00422.geojsonFile found
# 00423.geojsonFile found
# 00424.geojsonFile found
# 00425.geojsonFile found
# 00426.geojsonFile found
# 00427.geojsonFile found
# 00428.geojsonFile found
# 00429.geojsonFile found
# 00430.geojsonFile found
# 00431.geojsonFile found
# 00432.geojsonFile found
# 00433.geojsonFile found
# 00434.geojsonFile found
# 00435.geojsonFile found
# 00436.geojsonFile found
# 00437.geojsonFile found
# 00438.geojsonFile found
# 00439.geojsonFile found
# 00440.geojsonFile found
# 00441.geojsonFile found
# 00442.geojsonFile found
# 00443.geojsonFile found
# 00444.geojsonFile found
# 00445.geojsonFile found
# 00446.geojsonFile found
# 00447.geojsonFile found
# 00448.geojsonFile found
# 00449.geojsonFile found
# 00450.geojsonFile found
# 00451.geojsonFile found
# 00452.geojsonFile found
# 00453.geojsonFile found
# 00454.geojsonFile found
# 00455.geojsonFile found
# 00456.geojsonFile found
# 00457.geojsonFile found
# 00458.geojsonFile found
# 00459.geojsonFile found
# 00460.geojsonFile found
# 00461.geojsonFile found
# 00462.geojsonFile found
# 00463.geojsonFile found
# 00464.geojsonFile found
# 00465.geojsonFile found
# 00466.geojsonFile found
# 00467.geojsonFile found
# 00468.geojsonFile found
# 00469.geojsonFile found
# 00470.geojsonFile found
# 00471.geojsonFile found
# 00472.geojsonFile found
# 00473.geojsonFile found
# 00474.geojsonFile found
# 00475.geojsonFile found
# 00476.geojsonFile found
# 00477.geojsonFile found
# 00478.geojsonFile found
# [2, 0.2952691267933655, 0.33342924615966957, 0.10545503125000064, 0.10545503125259918]
# 00479.geojsonFile found
# 00480.geojsonFile found
# 00481.geojsonFile found
# 00482.geojsonFile found
# [2, 0.6773638712025526, 0.5388260491350333, 0.08799729464278373, 0.08799729464226402]
# 00483.geojsonFile found
# [2, 0.0354667513329332, 0.8102094883049306, 0.05959146874998363, 0.07330233928431491]
# [2, 0.14557106743164436, 0.089409290646602, 0.08646809821428698, 0.08647135714168794]
# 00484.geojsonFile found
# 00485.geojsonFile found
# 00486.geojson does not exist
# 00487.geojson does not exist
# 00488.geojson does not exist
# 00489.geojson does not exist
# 00490.geojson does not exist
# 00491.geojson does not exist
# 00492.geojson does not exist
# 00493.geojsonFile found
# 00494.geojsonFile found
# 00495.geojsonFile found
# 00496.geojsonFile found
# 00497.geojsonFile found
# 00498.geojsonFile found
# 00499.geojsonFile found
# 00500.geojsonFile found
# 00501.geojsonFile found
# 00502.geojsonFile found
# 00503.geojsonFile found
# 00504.geojsonFile found
# 00505.geojsonFile found
# 00506.geojsonFile found
# 00507.geojsonFile found
# 00508.geojsonFile found
# 00509.geojsonFile found
# 00510.geojsonFile found
# 00511.geojsonFile found
# 00512.geojsonFile found
# 00513.geojsonFile found
# 00514.geojsonFile found
# 00515.geojsonFile found
# 00516.geojsonFile found
# 00517.geojsonFile found
# 00518.geojsonFile found
# 00519.geojsonFile found
# 00520.geojsonFile found
# 00521.geojsonFile found
# 00522.geojsonFile found
# 00523.geojsonFile found
# 00524.geojsonFile found
# 00525.geojsonFile found
# 00526.geojsonFile found
# 00527.geojsonFile found
# 00528.geojsonFile found
# 00529.geojsonFile found
# 00530.geojsonFile found
# 00531.geojsonFile found
# 00532.geojsonFile found
# 00533.geojsonFile found
# 00534.geojsonFile found
# 00535.geojsonFile found
# 00536.geojsonFile found
# 00537.geojsonFile found
# 00538.geojsonFile found
# 00539.geojsonFile found
# 00540.geojsonFile found
# 00541.geojsonFile found
# 00542.geojsonFile found
# 00543.geojsonFile found
# 00544.geojsonFile found
# 00545.geojsonFile found
# 00546.geojsonFile found
# 00547.geojsonFile found
# 00548.geojsonFile found
# 00549.geojsonFile found
# 00550.geojsonFile found
# 00551.geojsonFile found
# 00552.geojsonFile found
# 00553.geojsonFile found
# 00554.geojsonFile found
# 00555.geojsonFile found
# 00556.geojsonFile found
# 00557.geojsonFile found
# 00558.geojsonFile found
# 00559.geojsonFile found
# 00560.geojsonFile found
# 00561.geojsonFile found
# 00562.geojsonFile found
# 00563.geojsonFile found
# 00564.geojsonFile found
# 00565.geojsonFile found
# 00566.geojsonFile found
# 00567.geojsonFile found
# 00568.geojsonFile found
# 00569.geojsonFile found
# 00570.geojsonFile found
# 00571.geojsonFile found
# 00572.geojsonFile found
# 00573.geojsonFile found
# 00574.geojsonFile found
# 00575.geojsonFile found
# 00576.geojsonFile found
# 00577.geojsonFile found
# 00578.geojsonFile found
# 00579.geojsonFile found
# 00580.geojsonFile found
# 00581.geojsonFile found
# 00582.geojsonFile found
# 00583.geojsonFile found
# 00584.geojsonFile found
# 00585.geojsonFile found
# 00586.geojsonFile found
# 00587.geojsonFile found
# 00588.geojsonFile found
# 00589.geojsonFile found
# 00590.geojsonFile found
# 00591.geojsonFile found
# 00592.geojsonFile found
# 00593.geojsonFile found
# 00594.geojsonFile found
# 00595.geojsonFile found
# 00596.geojsonFile found
# 00597.geojsonFile found
# 00598.geojsonFile found
# 00599.geojsonFile found
# 00600.geojsonFile found
# 00601.geojsonFile found
# 00602.geojsonFile found
# 00603.geojsonFile found
# 00604.geojsonFile found
# 00605.geojsonFile found
# 00606.geojsonFile found
# 00607.geojsonFile found
# 00608.geojsonFile found
# 00609.geojsonFile found
# 00610.geojsonFile found
# 00611.geojsonFile found
# 00612.geojsonFile found
# 00613.geojsonFile found
# 00614.geojsonFile found
# 00615.geojsonFile found
# 00616.geojsonFile found
# 00617.geojsonFile found
# 00618.geojsonFile found
# 00619.geojsonFile found
# 00620.geojsonFile found
# 00621.geojsonFile found
# 00622.geojsonFile found
# 00623.geojsonFile found
# 00624.geojsonFile found
# 00625.geojsonFile found
# 00626.geojsonFile found
# 00627.geojsonFile found
# 00628.geojsonFile found
# 00629.geojsonFile found
# 00630.geojsonFile found
# 00631.geojsonFile found
# 00632.geojsonFile found
# 00633.geojsonFile found
# 00634.geojsonFile found
# 00635.geojsonFile found
# 00636.geojsonFile found
# 00637.geojsonFile found
# 00638.geojsonFile found
# 00639.geojsonFile found
# 00640.geojsonFile found
# 00641.geojsonFile found
# [2, 0.4843250553421967, 0.8665508821016245, 0.1015409419641011, 0.10154476785516765]
# 00642.geojsonFile found
# 00643.geojsonFile found
# [2, 0.21753136510674917, 0.16929823412959064, 0.10411292857133958, 0.10411293303643886]
# [2, 0.5812321805122858, 0.07061371272512977, 0.09170892410734918, 0.0917089196445886]
# [2, 0.6512206598033247, 0.6981462581482317, 0.07115955803575551, 0.07116224107033174]
# 00644.geojsonFile found
# [2, 0.19779102489207748, 0.8510850009084346, 0.08655082142857802, 0.0865540848213381]
# 00645.geojsonFile found
# [0, 0.5523806210936267, 0.5000318225398327, 0.11161650892868888, 0.11676804017874279]
# 00646.geojsonFile found
# 00647.geojsonFile found
# 00648.geojson does not exist
# 00649.geojson does not exist
# 00650.geojson does not exist
# 00651.geojson does not exist
# 00652.geojson does not exist
# 00653.geojson does not exist
# 00654.geojson does not exist
# 00655.geojsonFile found
# 00656.geojsonFile found
# 00657.geojsonFile found
# 00658.geojsonFile found
# 00659.geojsonFile found
# 00660.geojsonFile found
# 00661.geojsonFile found
# 00662.geojsonFile found
# 00663.geojsonFile found
# 00664.geojsonFile found
# 00665.geojsonFile found
# 00666.geojsonFile found
# 00667.geojsonFile found
# 00668.geojsonFile found
# 00669.geojsonFile found
# 00670.geojsonFile found
# 00671.geojsonFile found
# 00672.geojsonFile found
# 00673.geojsonFile found
# 00674.geojsonFile found
# 00675.geojsonFile found
# 00676.geojsonFile found
# 00677.geojsonFile found
# 00678.geojsonFile found
# 00679.geojsonFile found
# 00680.geojsonFile found
# 00681.geojsonFile found
# 00682.geojsonFile found
# 00683.geojsonFile found
# 00684.geojsonFile found
# 00685.geojsonFile found
# 00686.geojsonFile found
# 00687.geojsonFile found
# 00688.geojsonFile found
# 00689.geojsonFile found
# 00690.geojsonFile found
# 00691.geojsonFile found
# 00692.geojsonFile found
# 00693.geojsonFile found
# 00694.geojsonFile found
# 00695.geojsonFile found
# 00696.geojsonFile found
# 00697.geojsonFile found
# 00698.geojsonFile found
# 00699.geojsonFile found
# 00700.geojsonFile found
# 00701.geojsonFile found
# 00702.geojsonFile found
# 00703.geojsonFile found
# 00704.geojsonFile found
# 00705.geojsonFile found
# 00706.geojsonFile found
# 00707.geojsonFile found
# 00708.geojsonFile found
# 00709.geojsonFile found
# 00710.geojsonFile found
# 00711.geojsonFile found
# 00712.geojsonFile found
# 00713.geojsonFile found
# 00714.geojsonFile found
# 00715.geojsonFile found
# 00716.geojsonFile found
# 00717.geojsonFile found
# 00718.geojsonFile found
# 00719.geojsonFile found
# 00720.geojsonFile found
# 00721.geojsonFile found
# 00722.geojsonFile found
# 00723.geojsonFile found
# 00724.geojsonFile found
# 00725.geojsonFile found
# 00726.geojsonFile found
# 00727.geojsonFile found
# 00728.geojsonFile found
# 00729.geojsonFile found
# 00730.geojsonFile found
# 00731.geojsonFile found
# 00732.geojsonFile found
# 00733.geojsonFile found
# 00734.geojsonFile found
# 00735.geojsonFile found
# 00736.geojsonFile found
# 00737.geojsonFile found
# 00738.geojsonFile found
# 00739.geojsonFile found
# 00740.geojsonFile found
# 00741.geojsonFile found
# 00742.geojsonFile found
# 00743.geojsonFile found
# 00744.geojsonFile found
# 00745.geojsonFile found
# 00746.geojsonFile found
# 00747.geojsonFile found
# 00748.geojsonFile found
# 00749.geojsonFile found
# 00750.geojsonFile found
# 00751.geojsonFile found
# 00752.geojsonFile found
# 00753.geojsonFile found
# 00754.geojsonFile found
# 00755.geojsonFile found
# 00756.geojsonFile found
# 00757.geojsonFile found
# 00758.geojsonFile found
# 00759.geojsonFile found
# 00760.geojsonFile found
# 00761.geojsonFile found
# 00762.geojsonFile found
# 00763.geojsonFile found
# 00764.geojsonFile found
# 00765.geojsonFile found
# 00766.geojsonFile found
# 00767.geojsonFile found
# 00768.geojsonFile found
# 00769.geojsonFile found
# 00770.geojsonFile found
# 00771.geojsonFile found
# 00772.geojsonFile found
# 00773.geojsonFile found
# 00774.geojsonFile found
# 00775.geojsonFile found
# 00776.geojsonFile found
# 00777.geojsonFile found
# 00778.geojsonFile found
# 00779.geojsonFile found
# 00780.geojsonFile found
# 00781.geojsonFile found
# 00782.geojsonFile found
# 00783.geojsonFile found
# 00784.geojsonFile found
# 00785.geojsonFile found
# 00786.geojsonFile found
# 00787.geojsonFile found
# 00788.geojsonFile found
# 00789.geojsonFile found
# 00790.geojsonFile found
# 00791.geojsonFile found
# 00792.geojsonFile found
# 00793.geojsonFile found
# 00794.geojsonFile found
# 00795.geojsonFile found
# 00796.geojsonFile found
# 00797.geojsonFile found
# 00798.geojsonFile found
# 00799.geojsonFile found
# 00800.geojsonFile found
# 00801.geojsonFile found
# 00802.geojsonFile found
# 00803.geojsonFile found
# 00804.geojsonFile found
# 00805.geojsonFile found
# 00806.geojsonFile found
# [2, 0.7492865281835422, 0.1343912354911611, 0.13192154017841468, 0.1319215401765957]
# 00807.geojsonFile found
# 00808.geojsonFile found
# 00809.geojsonFile found
# 00810.geojson does not exist
# 00811.geojson does not exist
# 00812.geojson does not exist
# 00813.geojson does not exist
# 00814.geojson does not exist
# 00815.geojson does not exist
# 00816.geojson does not exist
# 00817.geojsonFile found
# 00818.geojsonFile found
# 00819.geojsonFile found
# 00820.geojsonFile found
# 00821.geojsonFile found
# 00822.geojsonFile found
# 00823.geojsonFile found
# 00824.geojsonFile found
# 00825.geojsonFile found
# 00826.geojsonFile found
# 00827.geojsonFile found
# 00828.geojsonFile found
# 00829.geojsonFile found
# 00830.geojsonFile found
# 00831.geojsonFile found
# 00832.geojsonFile found
# 00833.geojsonFile found
# 00834.geojsonFile found
# 00835.geojsonFile found
# 00836.geojsonFile found
# 00837.geojsonFile found
# 00838.geojsonFile found
# 00839.geojsonFile found
# 00840.geojsonFile found
# 00841.geojsonFile found
# 00842.geojsonFile found
# 00843.geojsonFile found
# 00844.geojsonFile found
# 00845.geojsonFile found
# 00846.geojsonFile found
# 00847.geojsonFile found
# 00848.geojsonFile found
# 00849.geojsonFile found
# 00850.geojsonFile found
# 00851.geojsonFile found
# 00852.geojsonFile found
# 00853.geojsonFile found
# 00854.geojsonFile found
# 00855.geojsonFile found
# 00856.geojsonFile found
# 00857.geojsonFile found
# 00858.geojsonFile found
# 00859.geojsonFile found
# 00860.geojsonFile found
# 00861.geojsonFile found
# 00862.geojsonFile found
# 00863.geojsonFile found
# 00864.geojsonFile found
# 00865.geojsonFile found
# 00866.geojsonFile found
# 00867.geojsonFile found
# 00868.geojsonFile found
# 00869.geojsonFile found
# 00870.geojsonFile found
# 00871.geojsonFile found
# 00872.geojsonFile found
# 00873.geojsonFile found
# 00874.geojsonFile found
# 00875.geojsonFile found
# 00876.geojsonFile found
# 00877.geojsonFile found
# 00878.geojsonFile found
# 00879.geojsonFile found
# 00880.geojsonFile found
# 00881.geojsonFile found
# 00882.geojsonFile found
# 00883.geojsonFile found
# 00884.geojsonFile found
# 00885.geojsonFile found
# 00886.geojsonFile found
# 00887.geojsonFile found
# 00888.geojsonFile found
# 00889.geojsonFile found
# 00890.geojsonFile found
# 00891.geojsonFile found
# 00892.geojsonFile found
# 00893.geojsonFile found
# 00894.geojsonFile found
# 00895.geojsonFile found
# 00896.geojsonFile found
# 00897.geojsonFile found
# 00898.geojsonFile found
# 00899.geojsonFile found
# 00900.geojsonFile found
# 00901.geojsonFile found
# 00902.geojsonFile found
# 00903.geojsonFile found
# 00904.geojsonFile found
# 00905.geojsonFile found
# 00906.geojsonFile found
# 00907.geojsonFile found
# 00908.geojsonFile found
# 00909.geojsonFile found
# 00910.geojsonFile found
# 00911.geojsonFile found
# 00912.geojsonFile found
# 00913.geojsonFile found
# 00914.geojsonFile found
# 00915.geojsonFile found
# 00916.geojsonFile found
# 00917.geojsonFile found
# 00918.geojsonFile found
# 00919.geojsonFile found
# 00920.geojsonFile found
# 00921.geojsonFile found
# 00922.geojsonFile found
# 00923.geojsonFile found
# 00924.geojsonFile found
# 00925.geojsonFile found
# 00926.geojsonFile found
# 00927.geojsonFile found
# 00928.geojsonFile found
# 00929.geojsonFile found
# 00930.geojsonFile found
# 00931.geojsonFile found
# 00932.geojsonFile found
# 00933.geojsonFile found
# 00934.geojsonFile found
# 00935.geojsonFile found
# 00936.geojsonFile found
# 00937.geojsonFile found
# 00938.geojsonFile found
# 00939.geojsonFile found
# 00940.geojsonFile found
# 00941.geojsonFile found
# 00942.geojsonFile found
# 00943.geojsonFile found
# 00944.geojsonFile found
# 00945.geojsonFile found
# 00946.geojsonFile found
# 00947.geojsonFile found
# 00948.geojsonFile found
# 00949.geojsonFile found
# 00950.geojsonFile found
# 00951.geojsonFile found
# 00952.geojsonFile found
# 00953.geojsonFile found
# 00954.geojsonFile found
# 00955.geojsonFile found
# 00956.geojsonFile found
# 00957.geojsonFile found
# 00958.geojsonFile found
# 00959.geojsonFile found
# 00960.geojsonFile found
# 00961.geojsonFile found
# 00962.geojsonFile found
# 00963.geojsonFile found
# 00964.geojsonFile found
# 00965.geojsonFile found
# 00966.geojsonFile found
# 00967.geojsonFile found
# 00968.geojsonFile found
# [2, 0.7869486379996877, 0.8002541800877745, 0.09810068749980669, 0.098104388390701]
# 00969.geojsonFile found
# [2, 0.35427365520029397, 0.07262339675799012, 0.11235825446445753, 0.11235825446367796]
# [2, 0.7356004096878418, 0.9277736510183396, 0.08929934374983921, 0.08929934375087864]
# 00970.geojsonFile found
# [2, 0.0814980436415291, 0.6515313053969294, 0.08696652232148543, 0.08696652232070587]
# [2, 0.896235725353368, 0.6156300070080241, 0.09402088839280102, 0.09402088839228132]
# 00971.geojsonFile found
# 00972.geojson does not exist
# 00973.geojson does not exist
# 00974.geojson does not exist
# 00975.geojson does not exist
# 00976.geojson does not exist
# 00977.geojson does not exist
# 00978.geojson does not exist
# 00979.geojsonFile found
# 00980.geojsonFile found
# 00981.geojsonFile found
# 00982.geojsonFile found
# 00983.geojsonFile found
# 00984.geojsonFile found
# 00985.geojsonFile found
# 00986.geojsonFile found
# 00987.geojsonFile found
# 00988.geojsonFile found
# 00989.geojsonFile found
# 00990.geojsonFile found
# 00991.geojsonFile found
# 00992.geojsonFile found
# 00993.geojsonFile found
# 00994.geojsonFile found
# 00995.geojsonFile found
# 00996.geojsonFile found
# 00997.geojsonFile found
# 00998.geojsonFile found
# 00999.geojsonFile found
# 01000.geojsonFile found
# 01001.geojsonFile found
# 01002.geojsonFile found
# 01003.geojsonFile found
# 01004.geojsonFile found
# 01005.geojsonFile found
# 01006.geojsonFile found
# 01007.geojsonFile found
# 01008.geojsonFile found
# 01009.geojsonFile found
# 01010.geojsonFile found
# 01011.geojsonFile found
# 01012.geojsonFile found
# 01013.geojsonFile found
# 01014.geojsonFile found
# 01015.geojsonFile found
# 01016.geojsonFile found
# 01017.geojsonFile found
# 01018.geojsonFile found
# 01019.geojsonFile found
# 01020.geojsonFile found
# 01021.geojsonFile found
# 01022.geojsonFile found
# 01023.geojsonFile found
# 01024.geojsonFile found
# 01025.geojsonFile found
# 01026.geojsonFile found
# 01027.geojsonFile found
# 01028.geojsonFile found
# 01029.geojsonFile found
# 01030.geojsonFile found
# 01031.geojsonFile found
# 01032.geojsonFile found
# 01033.geojsonFile found
# 01034.geojsonFile found
# 01035.geojsonFile found
# 01036.geojsonFile found
# 01037.geojsonFile found
# 01038.geojsonFile found
# 01039.geojsonFile found
# 01040.geojsonFile found
# 01041.geojsonFile found
# 01042.geojsonFile found
# 01043.geojsonFile found
# 01044.geojsonFile found
# 01045.geojsonFile found
# 01046.geojsonFile found
# 01047.geojsonFile found
# 01048.geojsonFile found
# 01049.geojsonFile found
# 01050.geojsonFile found
# 01051.geojsonFile found
# 01052.geojsonFile found
# 01053.geojsonFile found
# 01054.geojsonFile found
# 01055.geojsonFile found
# 01056.geojsonFile found
# 01057.geojsonFile found
# 01058.geojsonFile found
# 01059.geojsonFile found
# 01060.geojsonFile found
# 01061.geojsonFile found
# 01062.geojsonFile found
# 01063.geojsonFile found
# 01064.geojsonFile found
# 01065.geojsonFile found
# 01066.geojsonFile found
# 01067.geojsonFile found
# 01068.geojsonFile found
# 01069.geojsonFile found
# 01070.geojsonFile found
# 01071.geojsonFile found
# 01072.geojsonFile found
# 01073.geojsonFile found
# 01074.geojsonFile found
# 01075.geojsonFile found
# 01076.geojsonFile found
# 01077.geojsonFile found
# 01078.geojsonFile found
# 01079.geojsonFile found
# 01080.geojsonFile found
# 01081.geojsonFile found
# 01082.geojsonFile found
# 01083.geojsonFile found
# 01084.geojsonFile found
# 01085.geojsonFile found
# 01086.geojsonFile found
# 01087.geojsonFile found
# 01088.geojsonFile found
# 01089.geojsonFile found
# 01090.geojsonFile found
# 01091.geojsonFile found
# 01092.geojsonFile found
# 01093.geojsonFile found
# 01094.geojsonFile found
# 01095.geojsonFile found
# 01096.geojsonFile found
# 01097.geojsonFile found
# 01098.geojsonFile found
# 01099.geojsonFile found
# 01100.geojsonFile found
# 01101.geojsonFile found
# 01102.geojsonFile found
# 01103.geojsonFile found
# 01104.geojsonFile found
# 01105.geojsonFile found
# 01106.geojsonFile found
# 01107.geojsonFile found
# 01108.geojsonFile found
# 01109.geojsonFile found
# 01110.geojsonFile found
# 01111.geojsonFile found
# 01112.geojsonFile found
# 01113.geojsonFile found
# 01114.geojsonFile found
# 01115.geojsonFile found
# 01116.geojsonFile found
# 01117.geojsonFile found
# 01118.geojsonFile found
# 01119.geojsonFile found
# 01120.geojsonFile found
# 01121.geojsonFile found
# 01122.geojsonFile found
# 01123.geojsonFile found
# 01124.geojsonFile found
# 01125.geojsonFile found
# 01126.geojsonFile found
# 01127.geojsonFile found
# 01128.geojsonFile found
# 01129.geojsonFile found
# [2, 0.5698000641981967, 0.6053929122281261, 0.0955275178572005, 0.09553111160805981]
# 01130.geojsonFile found
# [2, 0.12028421865086004, 0.8259324043590043, 0.09459633035736001, 0.094596330359179]
# [2, 0.8532801747969643, 0.5122653696785814, 0.1059637366070092, 0.10596772321566407]
# 01131.geojsonFile found
# [2, 0.6643144209777218, 0.052299841169899865, 0.1015447678572465, 0.10154476339396622]
# [2, 0.6726891107217463, 0.11695473476512623, 0.06570070089297328, 0.06570317410764151]
# [2, 0.704991485697974, 0.4866282218842701, 0.07241558928581071, 0.07241831696176503]
# 01132.geojsonFile found
# [2, 0.8736816665823426, 0.2878350249624678, 0.08415291964281225, 0.0841560892877169]
# 01133.geojsonFile found
# 01134.geojson does not exist
# 01135.geojson does not exist
# 01136.geojson does not exist
# 01137.geojson does not exist
# 01138.geojson does not exist
# 01139.geojson does not exist
# 01140.geojson does not exist
# 01141.geojsonFile found
# 01142.geojsonFile found
# 01143.geojsonFile found
# 01144.geojsonFile found
# 01145.geojsonFile found
# 01146.geojsonFile found
# 01147.geojsonFile found
# 01148.geojsonFile found
# 01149.geojsonFile found
# 01150.geojsonFile found
# 01151.geojsonFile found
# 01152.geojsonFile found
# 01153.geojsonFile found
# 01154.geojsonFile found
# 01155.geojsonFile found
# 01156.geojsonFile found
# 01157.geojsonFile found
# 01158.geojsonFile found
# 01159.geojsonFile found
# 01160.geojsonFile found
# 01161.geojsonFile found
# 01162.geojsonFile found
# 01163.geojsonFile found
# 01164.geojsonFile found
# 01165.geojsonFile found
# 01166.geojsonFile found
# 01167.geojsonFile found
# 01168.geojsonFile found
# 01169.geojsonFile found
# 01170.geojsonFile found
# 01171.geojsonFile found
# 01172.geojsonFile found
# 01291.geojsonFile found
# 01292.geojsonFile found
# [2, 0.18875526520995273, 0.4652080176788981, 0.09682314732136936, 0.09682314731929052]
# [2, 0.9174722022268854, 0.5957350401856404, 0.08459048214276013, 0.08459048214302]
# 01293.geojsonFile found
# [2, 0.2206331021882631, 0.3478228084111054, 0.09044830803551511, 0.09045171428754527]
# [2, 0.974176862834221, 0.735998876733772, 0.04128734821434981, 0.08353657143223765]
# 01294.geojsonFile found
# 01295.geojsonFile found
# [2, 0.5855303016770839, 0.8690891451426849, 0.09242059375018082, 0.09242407142716859]
# 01296.geojson does not exist
# [2, 0.5855303016770839, 0.8690891451426849, 0.09242059375018082, 0.09242407142716859]
# 01297.geojson does not exist
# [2, 0.5855303016770839, 0.8690891451426849, 0.09242059375018082, 0.09242407142716859]
# 01298.geojson does not exist
# [2, 0.5855303016770839, 0.8690891451426849, 0.09242059375018082, 0.09242407142716859]
# 01299.geojson does not exist
# [2, 0.5855303016770839, 0.8690891451426849, 0.09242059375018082, 0.09242407142716859]
# 01300.geojson does not exist
# [2, 0.5855303016770839, 0.8690891451426849, 0.09242059375018082, 0.09242407142716859]
# 01301.geojson does not exist
# [2, 0.5855303016770839, 0.8690891451426849, 0.09242059375018082, 0.09242407142716859]
# 01302.geojson does not exist
# [2, 0.5855303016770839, 0.8690891451426849, 0.09242059375018082, 0.09242407142716859]
# 01303.geojsonFile found
# 01304.geojsonFile found
# 01305.geojsonFile found
# 01306.geojsonFile found
# 01307.geojsonFile found
# 01308.geojsonFile found
# 01309.geojsonFile found
# 01310.geojsonFile found
# 01311.geojsonFile found
# 01312.geojsonFile found
# 01313.geojsonFile found
# 01314.geojsonFile found
# 01315.geojsonFile found
# 01316.geojsonFile found
# 01317.geojsonFile found
# 01318.geojsonFile found
# 01319.geojsonFile found
# 01320.geojsonFile found
# 01321.geojsonFile found
# 01322.geojsonFile found
# 01323.geojsonFile found
# 01324.geojsonFile found
# 01325.geojsonFile found
# 01326.geojsonFile found
# 01327.geojsonFile found
# 01328.geojsonFile found
# 01329.geojsonFile found
# 01330.geojsonFile found
# 01331.geojsonFile found
# 01332.geojsonFile found
# 01333.geojsonFile found
# 01334.geojsonFile found
# 01335.geojsonFile found
# 01336.geojsonFile found
# 01337.geojsonFile found
# 01338.geojsonFile found
# 01339.geojsonFile found
# 01340.geojsonFile found
# 01341.geojsonFile found
# 01342.geojsonFile found
# 01343.geojsonFile found
# 01344.geojsonFile found
# 01345.geojsonFile found
# 01346.geojsonFile found
# 01347.geojsonFile found
# 01348.geojsonFile found
# 01349.geojsonFile found
# 01350.geojsonFile found
# 01351.geojsonFile found
# 01352.geojsonFile found
# 01353.geojsonFile found
# 01354.geojsonFile found
# 01355.geojsonFile found
# 01356.geojsonFile found
# 01357.geojsonFile found
# 01358.geojsonFile found
# 01359.geojsonFile found
# 01360.geojsonFile found
# 01361.geojsonFile found
# 01362.geojsonFile found
# 01363.geojsonFile found
# 01364.geojsonFile found
# 01365.geojsonFile found
# 01366.geojsonFile found
# 01367.geojsonFile found
# 01368.geojsonFile found
# 01369.geojsonFile found
# 01370.geojsonFile found
# 01371.geojsonFile found
# 01372.geojsonFile found
# 01373.geojsonFile found
# 01374.geojsonFile found
# 01375.geojsonFile found
# 01376.geojsonFile found
# 01377.geojsonFile found
# 01378.geojsonFile found
# 01379.geojsonFile found
# 01380.geojsonFile found
# 01381.geojsonFile found
# 01382.geojsonFile found
# 01383.geojsonFile found
# 01384.geojsonFile found
# 01385.geojsonFile found
# 01386.geojsonFile found
# 01387.geojsonFile found
# 01388.geojsonFile found
# 01389.geojsonFile found
# 01390.geojsonFile found
# 01391.geojsonFile found
# 01392.geojsonFile found
# 01393.geojsonFile found
# 01394.geojsonFile found
# 01395.geojsonFile found
# 01396.geojsonFile found
# 01397.geojsonFile found
# 01398.geojsonFile found
# 01399.geojsonFile found
# 01400.geojsonFile found
# 01401.geojsonFile found
# 01402.geojsonFile found
# 01403.geojsonFile found
# 01404.geojsonFile found
# 01405.geojsonFile found
# 01406.geojsonFile found
# 01407.geojsonFile found
# 01408.geojsonFile found
# 01409.geojsonFile found
# 01410.geojsonFile found
# 01411.geojsonFile found
# 01412.geojsonFile found
# 01413.geojsonFile found
# 01414.geojsonFile found
# 01415.geojsonFile found
# 01416.geojsonFile found
# 01417.geojsonFile found
# 01418.geojsonFile found
# 01419.geojsonFile found
# 01420.geojsonFile found
# 01421.geojsonFile found
# 01422.geojsonFile found
# 01423.geojsonFile found
# 01424.geojsonFile found
# 01425.geojsonFile found
# 01426.geojsonFile found
# 01427.geojsonFile found
# 01428.geojsonFile found
# 01429.geojsonFile found
# 01430.geojsonFile found
# 01431.geojsonFile found
# 01432.geojsonFile found
# 01433.geojsonFile found
# 01434.geojsonFile found
# 01435.geojsonFile found
# 01436.geojsonFile found
# 01437.geojsonFile found
# 01438.geojsonFile found
# 01439.geojsonFile found
# 01440.geojsonFile found
# 01441.geojsonFile found
# 01442.geojsonFile found
# 01443.geojsonFile found
# 01444.geojsonFile found
# 01445.geojsonFile found
# 01446.geojsonFile found
# 01447.geojsonFile found
# 01448.geojsonFile found
# 01449.geojsonFile found
# 01450.geojsonFile found
# 01451.geojsonFile found
# 01452.geojsonFile found
# 01453.geojsonFile found
# [2, 0.35093682803277, 0.11904655903344974, 0.09413487053565664, 0.09413841964643714]
# 01454.geojsonFile found
# [2, 0.7826898459144493, 0.3971795830501443, 0.09157155803586647, 0.09157500446391557]
# [2, 0.40699197691459893, 0.5345317453570065, 0.09472815178586254, 0.09473171875080359]
# 01455.geojsonFile found
# [2, 0.026494335283132386, 0.7355423560989688, 0.042257691964290904, 0.08354504018123927]
# [2, 0.9363066284383551, 0.43226329512461753, 0.08926653124996976, 0.08926653125256832]
# 01456.geojsonFile found
# [2, 0.8609958938834877, 0.7861090031469108, 0.10545503125000064, 0.10545503571380063]
# 01457.geojsonFile found
# 01458.geojson does not exist
# 01459.geojson does not exist
# 01460.geojson does not exist
# 01461.geojson does not exist
# 01462.geojson does not exist
# 01463.geojson does not exist
# 01464.geojson does not exist
# 01583.geojsonFile found
# 01584.geojsonFile found
# 01585.geojsonFile found
# 01586.geojsonFile found
# 01587.geojsonFile found
# 01588.geojsonFile found
# 01589.geojsonFile found
# 01590.geojsonFile found
# 01591.geojsonFile found
# 01592.geojsonFile found
# 01593.geojsonFile found
# 01594.geojsonFile found
# 01595.geojsonFile found
# 01596.geojsonFile found
# 01597.geojsonFile found
# 01598.geojsonFile found
# 01599.geojsonFile found
# 01600.geojsonFile found
# 01601.geojsonFile found
# 01602.geojsonFile found
# 01603.geojsonFile found
# 01604.geojsonFile found
# 01605.geojsonFile found
# 01606.geojsonFile found
# 01607.geojsonFile found
# 01608.geojsonFile found
# 01609.geojsonFile found
# 01610.geojsonFile found
# 01611.geojsonFile found
# 01612.geojsonFile found
# 01613.geojsonFile found
# 01614.geojsonFile found
# 01615.geojsonFile found
# [2, 0.16849981037661824, 0.036377912462090274, 0.11203746428587433, 0.06583944642833169]
# 01616.geojsonFile found
# [2, 0.16822945865091501, 0.9661230607556978, 0.11030348660720588, 0.04620223660770405]
# 01617.geojsonFile found
# [2, 0.3992964849335944, 0.5875908558456493, 0.09035991517859136, 0.09036331696136456]
# 01618.geojsonFile found
# 01619.geojsonFile found
# 01620.geojson does not exist
# 01621.geojson does not exist
# 01622.geojson does not exist
# 01623.geojson does not exist
# 01624.geojson does not exist
# 01625.geojson does not exist
# 01626.geojson does not exist
# 01627.geojsonFile found
# 01628.geojsonFile found
# 01629.geojsonFile found
# 01630.geojsonFile found
# 01631.geojsonFile found
# 01632.geojsonFile found
# 01633.geojsonFile found
# 01634.geojsonFile found
# 01635.geojsonFile found
# 01636.geojsonFile found
# 01637.geojsonFile found
# 01638.geojsonFile found
# 01639.geojsonFile found
# 01640.geojsonFile found
# 01641.geojsonFile found
# 01642.geojsonFile found
# 01643.geojsonFile found
# 01644.geojsonFile found
# 01645.geojsonFile found
# 01646.geojsonFile found
# 01647.geojsonFile found
# 01648.geojsonFile found
# 01649.geojsonFile found
# 01650.geojsonFile found
# 01651.geojsonFile found
# 01652.geojsonFile found
# 01653.geojsonFile found
# 01654.geojsonFile found
# 01655.geojsonFile found
# 01656.geojsonFile found
# 01657.geojsonFile found
# 01658.geojsonFile found
# 01659.geojsonFile found
# 01660.geojsonFile found
# 01661.geojsonFile found
# 01662.geojsonFile found
# 01663.geojsonFile found
# 01664.geojsonFile found
# 01665.geojsonFile found
# 01666.geojsonFile found
# 01667.geojsonFile found
# 01668.geojsonFile found
# 01669.geojsonFile found
# 01670.geojsonFile found
# 01671.geojsonFile found
# 01672.geojsonFile found
# 01673.geojsonFile found
# 01674.geojsonFile found
# 01675.geojsonFile found
# 01676.geojsonFile found
# 01677.geojsonFile found
# 01678.geojsonFile found
# 01679.geojsonFile found
# 01680.geojsonFile found
# 01681.geojsonFile found
# 01682.geojsonFile found
# 01683.geojsonFile found
# 01684.geojsonFile found
# 01685.geojsonFile found
# 01686.geojsonFile found
# 01687.geojsonFile found
# 01688.geojsonFile found
# 01689.geojsonFile found
# 01690.geojsonFile found
# 01691.geojsonFile found
# 01692.geojsonFile found
# 01693.geojsonFile found
# 01694.geojsonFile found
# 01695.geojsonFile found
# 01696.geojsonFile found
# 01697.geojsonFile found
# 01698.geojsonFile found
# 01699.geojsonFile found
# 01700.geojsonFile found
# 01701.geojsonFile found
# 01702.geojsonFile found
# 01703.geojsonFile found
# 01704.geojsonFile found
# 01705.geojsonFile found
# 01706.geojsonFile found
# 01707.geojsonFile found
# 01708.geojsonFile found
# 01709.geojsonFile found
# 01710.geojsonFile found
# 01711.geojsonFile found
# 01712.geojsonFile found
# 01713.geojsonFile found
# 01714.geojsonFile found
# 01715.geojsonFile found
# 01716.geojsonFile found
# 01717.geojsonFile found
# 01718.geojsonFile found
# 01719.geojsonFile found
# 01720.geojsonFile found
# 01721.geojsonFile found
# 01722.geojsonFile found
# 01723.geojsonFile found
# 01724.geojsonFile found
# 01725.geojsonFile found
# 01726.geojsonFile found
# 01727.geojsonFile found
# 01728.geojsonFile found
# 01729.geojsonFile found
# 01730.geojsonFile found
# 01731.geojsonFile found
# 01732.geojsonFile found
# 01733.geojsonFile found
# 01734.geojsonFile found
# 01735.geojsonFile found
# 01736.geojsonFile found
# 01737.geojsonFile found
# 01738.geojsonFile found
# 01739.geojsonFile found
# 01740.geojsonFile found
# 01741.geojsonFile found
# 01742.geojsonFile found
# 01743.geojsonFile found
# 01744.geojsonFile found
# 01745.geojsonFile found
# 01746.geojsonFile found
# 01747.geojsonFile found
# 01748.geojsonFile found
# 01749.geojsonFile found
# 01750.geojsonFile found
# 01751.geojsonFile found
# 01752.geojsonFile found
# 01753.geojsonFile found
# 01754.geojsonFile found
# 01755.geojsonFile found
# 01756.geojsonFile found
# 01757.geojsonFile found
# 01758.geojsonFile found
# 01759.geojsonFile found
# 01760.geojsonFile found
# 01761.geojsonFile found
# 01762.geojsonFile found
# 01763.geojsonFile found
# 01764.geojsonFile found
# 01765.geojsonFile found
# 01766.geojsonFile found
# 01767.geojsonFile found
# 01768.geojsonFile found
# 01769.geojsonFile found
# 01770.geojsonFile found
# 01771.geojsonFile found
# 01772.geojsonFile found
# 01773.geojsonFile found
# 01774.geojsonFile found
# 01775.geojsonFile found
# 01776.geojsonFile found
# ...
# 34603.geojson does not exist
# 34604.geojson does not exist
# 34605.geojson does not exist
# 34606.geojson does not exist
# 34607.geojson does not exist
# 34608.geojson does not exist
# 34609.geojson does not exist
# 34610.geojson does not exist
# 34611.geojson does not exist
# 34612.geojson does not exist
# 34613.geojson does not exist
# 34614.geojson does not exist
# 34615.geojson does not exist
# 34616.geojson does not exist
# 34617.geojson does not exist
# 34618.geojson does not exist
# 34619.geojson does not exist
# 34620.geojson does not exist
# 34621.geojson does not exist
# 34622.geojson does not exist
# 34623.geojson does not exist
# 34624.geojson does not exist
# 34625.geojson does not exist
# 34626.geojson does not exist
# 34627.geojson does not exist
# 34628.geojson does not exist
# 34629.geojson does not exist
# 34630.geojson does not exist
# 34631.geojson does not exist
# 34632.geojson does not exist
# 34633.geojson does not exist
# 34634.geojson does not exist
# 35107.geojson does not exist
# 35108.geojson does not exist
# 35109.geojson does not exist
# 35110.geojson does not exist
# 35111.geojson does not exist
# 35112.geojson does not exist
# 35113.geojson does not exist
# 35114.geojson does not exist
# 35115.geojson does not exist
# 35116.geojson does not exist
# 35117.geojson does not exist
# 35118.geojson does not exist
# 35119.geojson does not exist
# 35120.geojson does not exist
# 35121.geojson does not exist
# 35122.geojson does not exist
# 35123.geojson does not exist
# 35124.geojson does not exist
# 35125.geojson does not exist
# 35126.geojson does not exist
# 35127.geojson does not exist
# 35128.geojson does not exist
# 35129.geojson does not exist
# 35130.geojson does not exist
# 35131.geojson does not exist
# 35132.geojson does not exist
# 35133.geojson does not exist
# 35134.geojson does not exist
# 35135.geojson does not exist
# 35136.geojson does not exist
# 35137.geojson does not exist
# 35138.geojson does not exist
# 35139.geojson does not exist
# 35140.geojson does not exist
# 35141.geojson does not exist
# 35142.geojson does not exist
# 35143.geojson does not exist
# 35144.geojson does not exist
# 35145.geojson does not exist
# 35146.geojson does not exist
# 35147.geojson does not exist
# 35148.geojson does not exist
# 35149.geojson does not exist
# 35150.geojson does not exist
# 35151.geojson does not exist
# 35152.geojson does not exist
# 35153.geojson does not exist
# Done

# %% [markdown]
# # Create two image folders "Labeled_images" and "No_labeles_images"

# %%
print("Start dividing images into the Labeled_images and No_label_images folder")

label_base_src_path = "GeoJSON"
label_base_target_path = "Labels"

image_base_src_path = "Images"
image_labeled_base_target_path = "Labeled_images"
image_no_label_base_target_path = "No_label_images"

contains_labels = 0
no_labels = 0
file_does_not_exist = 0

for i in range(max_x_tile*max_y_tile):
    
    
    file_name_geo = all_tiles[i] + ".geojson"
    src_path = os.path.join(label_base_src_path, file_name_geo)
    
    file_name_txt = all_tiles[i] + ".txt"
    target_path = os.path.join(label_base_target_path, file_name_txt)
    
    # Define src image e.g. 'Images/00000.tif
    file_name_tif = all_tiles[i] + ".tif"
    image_src_path = os.path.join(image_base_src_path, file_name_tif)
    image_labeled_target_path = os.path.join(image_labeled_base_target_path, file_name_tif)
    image_no_label_target_path = os.path.join(image_no_label_base_target_path, file_name_tif)
    
    
    
    # Load all GeoJSON files that exist
    try:
        f = open(src_path)
        json_file = geojson.load(f)
        #print(file_name_geo + "File found")
    
    except:
        file_does_not_exist += 1
    
    all_my_parameters = []

    # Get all needed parameters
    try:
        for j in range(len(json_file["features"])):
            all_my_parameters.append(find_parameters(json_file['features'][j]))   # Add for each feature the parameters that YOLOv5 needs
    
    except:
        print("Nothing detected in this image: " + file_name_geo)    
              
    
    # Save the images with and without labels in diffrent folders
    try:
        if all_my_parameters[0]:
            print(i, " has label")
            contains_labels += 1
            image = Image.open(image_src_path)
            image.save(image_labeled_target_path)
        
    except:
        #print(i)
        no_labels += 1
        image = Image.open(image_src_path)
        image.save(image_no_label_target_path)
    
    
print("Done")
print("Images with no labels: ", no_labels,", Images with labels: ", contains_labels)
# Out:
# Start dividing images into the Labeled_images and No_label_images folder
# 315  has label
# 316  has label
# 320  has label
# 321  has label
# 478  has label
# 482  has label
# 483  has label
# 641  has label
# 643  has label
# 644  has label
# 645  has label
# 806  has label
# 968  has label
# 969  has label
# 970  has label
# 1129  has label
# 1130  has label
# 1131  has label
# 1132  has label
# 1292  has label
# 1293  has label
# 1295  has label
# 1296  has label
# 1297  has label
# 1298  has label
# 1299  has label
# 1300  has label
# 1301  has label
# 1302  has label
# 1453  has label
# 1454  has label
# 1455  has label
# 1456  has label
# 1615  has label
# 1616  has label
# 1617  has label
# 2228  has label
# 2231  has label
# 2389  has label
# 2391  has label
# 2550  has label
# 2551  has label
# 2552  has label
# 2553  has label
# 2712  has label
# 2714  has label
# 2869  has label
# 2874  has label
# 2875  has label
# 2876  has label
# 2878  has label
# 2879  has label
# 3031  has label
# 3032  has label
# 3037  has label
# 3038  has label
# 3039  has label
# 3040  has label
# 3042  has label
# 3043  has label
# 3196  has label
# 3199  has label
# 3200  has label
# 3201  has label
# 3202  has label
# 3204  has label
# 3205  has label
# 3358  has label
# 3359  has label
# 3363  has label
# 3364  has label
# 3365  has label
# 3366  has label
# 3522  has label
# 3526  has label
# 3527  has label
# 3528  has label
# 3688  has label
# 3689  has label
# 3690  has label
# 3691  has label
# 3692  has label
# 3849  has label
# 3850  has label
# 3851  has label
# 3852  has label
# 3853  has label
# 3854  has label
# 3856  has label
# 4012  has label
# 4013  has label
# 4014  has label
# 4015  has label
# 4016  has label
# 4017  has label
# 4018  has label
# 4174  has label
# 4175  has label
# 4176  has label
# 4177  has label
# 4178  has label
# 4179  has label
# 4181  has label
# 4182  has label
# 4334  has label
# 4337  has label
# 4338  has label
# 4339  has label
# 4340  has label
# 4341  has label
# 4342  has label
# 4343  has label
# 4344  has label
# 4493  has label
# 4494  has label
# 4495  has label
# 4498  has label
# 4500  has label
# 4501  has label
# 4502  has label
# 4503  has label
# 4504  has label
# 4506  has label
# 4508  has label
# 4509  has label
# 4654  has label
# 4655  has label
# 4656  has label
# 4657  has label
# 4659  has label
# 4660  has label
# 4661  has label
# 4662  has label
# 4663  has label
# 4664  has label
# 4665  has label
# 4666  has label
# 4667  has label
# 4668  has label
# 4670  has label
# 4671  has label
# 4817  has label
# 4821  has label
# 4822  has label
# 4823  has label
# 4824  has label
# 4825  has label
# 4826  has label
# 4827  has label
# 4828  has label
# 4829  has label
# 4830  has label
# 4831  has label
# 4832  has label
# 4833  has label
# 4983  has label
# 4984  has label
# 4985  has label
# 4986  has label
# 4987  has label
# 4988  has label
# 4989  has label
# 4990  has label
# 4991  has label
# 5145  has label
# 5148  has label
# 5149  has label
# 5150  has label
# 5151  has label
# 5152  has label
# 5153  has label
# 5154  has label
# 5309  has label
# 5310  has label
# 5311  has label
# 5317  has label
# 5471  has label
# 5472  has label
# 5475  has label
# 5630  has label
# 5631  has label
# 5637  has label
# 5963  has label
# 6125  has label
# 6423  has label
# 6426  has label
# 6428  has label
# 6446  has label
# 6449  has label
# 6455  has label
# 6456  has label
# 6457  has label
# 6581  has label
# 6585  has label
# 6586  has label
# 6587  has label
# 6588  has label
# 6589  has label
# 6606  has label
# 6607  has label
# 6608  has label
# 6617  has label
# 6618  has label
# 6740  has label
# 6741  has label
# 6742  has label
# 6743  has label
# 6744  has label
# 6745  has label
# 6746  has label
# 6747  has label
# 6748  has label
# 6749  has label
# 6750  has label
# 6751  has label
# 6752  has label
# 6766  has label
# 6767  has label
# 6783  has label
# 6784  has label
# 6902  has label
# 6903  has label
# 6904  has label
# 6905  has label
# 6906  has label
# 6907  has label
# 6908  has label
# 6909  has label
# 6910  has label
# 6911  has label
# 6912  has label
# 6913  has label
# 6914  has label
# 6916  has label
# 6927  has label
# 6928  has label
# 6929  has label
# 6932  has label
# 6933  has label
# 6945  has label
# 6946  has label
# 7064  has label
# 7065  has label
# 7066  has label
# 7067  has label
# 7068  has label
# 7069  has label
# 7070  has label
# 7071  has label
# 7072  has label
# 7073  has label
# 7074  has label
# 7075  has label
# 7076  has label
# 7077  has label
# 7079  has label
# 7090  has label
# 7091  has label
# 7092  has label
# 7093  has label
# 7094  has label
# 7095  has label
# 7096  has label
# 7097  has label
# 7107  has label
# 7226  has label
# 7227  has label
# 7228  has label
# 7229  has label
# 7230  has label
# 7231  has label
# 7232  has label
# 7233  has label
# 7234  has label
# 7235  has label
# 7236  has label
# 7237  has label
# 7238  has label
# 7239  has label
# 7240  has label
# 7241  has label
# 7245  has label
# 7246  has label
# 7254  has label
# 7255  has label
# 7256  has label
# 7257  has label
# 7258  has label
# 7387  has label
# 7388  has label
# 7392  has label
# 7393  has label
# 7394  has label
# 7396  has label
# 7399  has label
# 7400  has label
# 7401  has label
# 7402  has label
# 7403  has label
# 7415  has label
# 7416  has label
# 7417  has label
# 7418  has label
# 7419  has label
# 7420  has label
# 7421  has label
# 7550  has label
# 7554  has label
# 7557  has label
# 7558  has label
# 7559  has label
# 7562  has label
# 7563  has label
# 7564  has label
# 7571  has label
# 7579  has label
# 7580  has label
# 7581  has label
# 7582  has label
# 7583  has label
# 7710  has label
# 7711  has label
# 7712  has label
# 7715  has label
# 7716  has label
# 7718  has label
# 7719  has label
# 7720  has label
# 7722  has label
# 7726  has label
# 7734  has label
# 7735  has label
# 7741  has label
# 7742  has label
# 7743  has label
# 7744  has label
# 7762  has label
# 7874  has label
# 7876  has label
# 7877  has label
# 7881  has label
# 7883  has label
# 7892  has label
# 7893  has label
# 7895  has label
# 7896  has label
# 7897  has label
# 7898  has label
# 7904  has label
# 7905  has label
# 7906  has label
# 7912  has label
# 7977  has label
# 7978  has label
# 8039  has label
# 8040  has label
# 8043  has label
# 8045  has label
# 8053  has label
# 8054  has label
# 8055  has label
# 8057  has label
# 8067  has label
# 8068  has label
# 8074  has label
# 8075  has label
# 8085  has label
# 8087  has label
# 8139  has label
# 8140  has label
# 8141  has label
# 8142  has label
# 8143  has label
# 8148  has label
# 8149  has label
# 8200  has label
# 8201  has label
# 8202  has label
# 8215  has label
# 8216  has label
# 8217  has label
# 8218  has label
# 8219  has label
# 8221  has label
# 8222  has label
# 8223  has label
# 8233  has label
# 8234  has label
# 8299  has label
# 8300  has label
# 8301  has label
# 8302  has label
# 8303  has label
# 8304  has label
# 8305  has label
# 8306  has label
# 8312  has label
# 8377  has label
# 8378  has label
# 8379  has label
# 8380  has label
# 8384  has label
# 8385  has label
# 8389  has label
# 8395  has label
# 8397  has label
# 8461  has label
# 8462  has label
# 8463  has label
# 8464  has label
# 8465  has label
# 8466  has label
# 8467  has label
# 8471  has label
# 8472  has label
# 8537  has label
# 8538  has label
# 8540  has label
# 8542  has label
# 8550  has label
# 8551  has label
# 8552  has label
# 8557  has label
# 8622  has label
# 8623  has label
# 8624  has label
# 8625  has label
# 8626  has label
# 8627  has label
# 8629  has label
# 8630  has label
# 8644  has label
# 8645  has label
# 8699  has label
# 8700  has label
# 8701  has label
# 8704  has label
# 8705  has label
# 8784  has label
# 8785  has label
# 8786  has label
# 8787  has label
# 8788  has label
# 8789  has label
# 8790  has label
# 8791  has label
# 8792  has label
# 8804  has label
# 8807  has label
# 8863  has label
# 8865  has label
# 8866  has label
# 8867  has label
# 8868  has label
# 8947  has label
# 8948  has label
# 8949  has label
# 8950  has label
# 8952  has label
# 8953  has label
# 8954  has label
# 8955  has label
# 8956  has label
# 8957  has label
# 8966  has label
# 8967  has label
# 9023  has label
# 9024  has label
# 9025  has label
# 9028  has label
# 9029  has label
# 9030  has label
# 9034  has label
# 9060  has label
# 9108  has label
# 9109  has label
# 9110  has label
# 9111  has label
# 9112  has label
# 9113  has label
# 9118  has label
# 9119  has label
# 9120  has label
# 9128  has label
# 9129  has label
# 9131  has label
# 9189  has label
# 9191  has label
# 9192  has label
# 9193  has label
# 9195  has label
# 9196  has label
# 9222  has label
# 9269  has label
# 9270  has label
# 9271  has label
# 9272  has label
# 9273  has label
# 9274  has label
# 9279  has label
# 9280  has label
# 9281  has label
# 9282  has label
# 9290  has label
# 9351  has label
# 9353  has label
# 9354  has label
# 9355  has label
# 9357  has label
# 9359  has label
# 9384  has label
# 9385  has label
# 9386  has label
# 9430  has label
# 9431  has label
# 9432  has label
# 9434  has label
# 9435  has label
# 9436  has label
# 9439  has label
# 9441  has label
# 9442  has label
# 9443  has label
# 9444  has label
# 9445  has label
# 9453  has label
# 9514  has label
# 9515  has label
# 9516  has label
# 9519  has label
# 9523  has label
# 9546  has label
# 9547  has label
# 9548  has label
# 9549  has label
# 9592  has label
# 9593  has label
# 9597  has label
# 9598  has label
# 9600  has label
# 9601  has label
# 9602  has label
# 9603  has label
# 9604  has label
# 9605  has label
# 9606  has label
# 9607  has label
# 9608  has label
# 9650  has label
# 9676  has label
# 9677  has label
# 9678  has label
# 9683  has label
# 9685  has label
# 9711  has label
# 9754  has label
# 9755  has label
# 9757  has label
# 9760  has label
# 9763  has label
# 9764  has label
# 9765  has label
# 9766  has label
# 9767  has label
# 9768  has label
# 9769  has label
# 9770  has label
# 9771  has label
# 9839  has label
# 9845  has label
# 9861  has label
# 9870  has label
# 9871  has label
# 9872  has label
# 9906  has label
# 9916  has label
# 9926  has label
# 9927  has label
# 9928  has label
# 9929  has label
# 9930  has label
# 9931  has label
# 9932  has label
# 9933  has label
# 9934  has label
# 10022  has label
# 10023  has label
# 10024  has label
# 10033  has label
# 10034  has label
# 10092  has label
# 10093  has label
# 10094  has label
# 10119  has label
# 10120  has label
# 10121  has label
# 10184  has label
# 10185  has label
# 10198  has label
# 10242  has label
# 10252  has label
# 10254  has label
# 10255  has label
# 10258  has label
# 10281  has label
# 10283  has label
# 10340  has label
# 10360  has label
# 10404  has label
# 10406  has label
# 10409  has label
# 10410  has label
# 10411  has label
# 10415  has label
# 10416  has label
# 10419  has label
# 10443  has label
# 10444  has label
# 10445  has label
# 10457  has label
# 10506  has label
# 10507  has label
# 10508  has label
# 10553  has label
# 10572  has label
# 10573  has label
# 10574  has label
# 10575  has label
# 10577  has label
# 10578  has label
# 10669  has label
# 10670  has label
# 10671  has label
# 10672  has label
# 10735  has label
# 10736  has label
# 10737  has label
# 10738  has label
# 10739  has label
# 10740  has label
# 10831  has label
# 10832  has label
# 10833  has label
# 10877  has label
# 10899  has label
# 10900  has label
# 10902  has label
# 10993  has label
# 10994  has label
# 11037  has label
# 11040  has label
# 11063  has label
# 11064  has label
# 11202  has label
# 11210  has label
# 11211  has label
# 11362  has label
# 11363  has label
# 11364  has label
# 11372  has label
# 11373  has label
# 11440  has label
# 11525  has label
# 11526  has label
# 11533  has label
# 11534  has label
# 11535  has label
# 11537  has label
# 11546  has label
# 11602  has label
# 11603  has label
# 11686  has label
# 11687  has label
# 11688  has label
# 11689  has label
# 11691  has label
# 11694  has label
# 11695  has label
# 11696  has label
# 11697  has label
# 11764  has label
# 11765  has label
# 11849  has label
# 11851  has label
# 11852  has label
# 11853  has label
# 11854  has label
# 11855  has label
# 11856  has label
# 11857  has label
# 11858  has label
# 11860  has label
# 11861  has label
# 11924  has label
# 11925  has label
# 12012  has label
# 12013  has label
# 12014  has label
# 12015  has label
# 12016  has label
# 12017  has label
# 12018  has label
# 12019  has label
# 12020  has label
# 12021  has label
# 12022  has label
# 12023  has label
# 12087  has label
# 12173  has label
# 12174  has label
# 12176  has label
# 12177  has label
# 12179  has label
# 12180  has label
# 12181  has label
# 12182  has label
# 12183  has label
# 12184  has label
# 12185  has label
# 12191  has label
# 12192  has label
# 12336  has label
# 12339  has label
# 12340  has label
# 12341  has label
# 12342  has label
# 12344  has label
# 12346  has label
# 12347  has label
# 12348  has label
# 12349  has label
# 12352  has label
# 12354  has label
# 12355  has label
# 12356  has label
# 12357  has label
# 12389  has label
# 12503  has label
# 12504  has label
# 12506  has label
# 12507  has label
# 12508  has label
# 12509  has label
# 12510  has label
# 12512  has label
# 12513  has label
# 12516  has label
# 12517  has label
# 12518  has label
# 12519  has label
# 12529  has label
# 12540  has label
# 12542  has label
# 12543  has label
# 12544  has label
# 12549  has label
# 12551  has label
# 12658  has label
# 12660  has label
# 12661  has label
# 12666  has label
# 12669  has label
# 12670  has label
# 12671  has label
# 12672  has label
# 12673  has label
# 12674  has label
# 12675  has label
# 12679  has label
# 12680  has label
# 12681  has label
# 12683  has label
# 12691  has label
# 12692  has label
# 12693  has label
# 12698  has label
# 12700  has label
# 12702  has label
# 12703  has label
# 12704  has label
# 12705  has label
# 12707  has label
# 12714  has label
# 12819  has label
# 12820  has label
# 12821  has label
# 12822  has label
# 12823  has label
# 12827  has label
# 12828  has label
# 12831  has label
# 12832  has label
# 12833  has label
# 12834  has label
# 12836  has label
# 12837  has label
# 12838  has label
# 12839  has label
# 12840  has label
# 12841  has label
# 12842  has label
# 12843  has label
# 12844  has label
# 12845  has label
# 12854  has label
# 12855  has label
# 12856  has label
# 12858  has label
# 12859  has label
# 12860  has label
# 12861  has label
# 12862  has label
# 12863  has label
# 12866  has label
# 12876  has label
# 12978  has label
# 12979  has label
# 12980  has label
# 12981  has label
# 12982  has label
# 12983  has label
# 12984  has label
# 12985  has label
# 12986  has label
# 12988  has label
# 12989  has label
# 12990  has label
# 12991  has label
# 12992  has label
# 12993  has label
# 12994  has label
# 12995  has label
# 12996  has label
# 12997  has label
# 12998  has label
# 12999  has label
# 13000  has label
# 13001  has label
# 13002  has label
# 13003  has label
# 13004  has label
# 13005  has label
# 13006  has label
# 13021  has label
# 13022  has label
# 13023  has label
# 13024  has label
# 13025  has label
# 13037  has label
# 13038  has label
# 13051  has label
# 13052  has label
# 13053  has label
# 13138  has label
# 13139  has label
# 13140  has label
# 13142  has label
# 13143  has label
# 13144  has label
# 13146  has label
# 13149  has label
# 13150  has label
# 13151  has label
# 13152  has label
# 13153  has label
# 13154  has label
# 13155  has label
# 13156  has label
# 13157  has label
# 13158  has label
# 13159  has label
# 13160  has label
# 13161  has label
# 13162  has label
# 13163  has label
# 13164  has label
# 13165  has label
# 13166  has label
# 13167  has label
# 13168  has label
# 13169  has label
# 13170  has label
# 13177  has label
# 13180  has label
# 13184  has label
# 13185  has label
# 13186  has label
# 13187  has label
# 13188  has label
# 13189  has label
# 13190  has label
# 13199  has label
# 13200  has label
# 13214  has label
# 13215  has label
# 13241  has label
# 13248  has label
# 13249  has label
# 13299  has label
# 13300  has label
# 13301  has label
# 13302  has label
# 13303  has label
# 13304  has label
# 13305  has label
# 13306  has label
# 13308  has label
# 13309  has label
# 13311  has label
# 13312  has label
# 13313  has label
# 13314  has label
# 13315  has label
# 13316  has label
# 13317  has label
# 13318  has label
# 13319  has label
# 13320  has label
# 13321  has label
# 13322  has label
# 13323  has label
# 13324  has label
# 13325  has label
# 13326  has label
# 13327  has label
# 13328  has label
# 13329  has label
# 13330  has label
# 13331  has label
# 13332  has label
# 13337  has label
# 13339  has label
# 13340  has label
# 13342  has label
# 13346  has label
# 13347  has label
# 13349  has label
# 13350  has label
# 13351  has label
# 13352  has label
# 13355  has label
# 13377  has label
# 13378  has label
# 13396  has label
# 13403  has label
# 13404  has label
# 13411  has label
# 13459  has label
# 13460  has label
# 13461  has label
# 13462  has label
# 13463  has label
# 13464  has label
# 13465  has label
# 13466  has label
# 13467  has label
# 13468  has label
# 13469  has label
# 13470  has label
# 13473  has label
# 13476  has label
# 13477  has label
# 13478  has label
# 13480  has label
# 13481  has label
# 13482  has label
# 13483  has label
# 13484  has label
# 13485  has label
# 13486  has label
# 13487  has label
# 13488  has label
# 13489  has label
# 13490  has label
# 13491  has label
# 13492  has label
# 13493  has label
# 13494  has label
# 13498  has label
# 13499  has label
# 13500  has label
# 13502  has label
# 13503  has label
# 13504  has label
# 13509  has label
# 13525  has label
# 13533  has label
# 13540  has label
# 13558  has label
# 13566  has label
# 13622  has label
# 13623  has label
# 13625  has label
# 13626  has label
# 13627  has label
# 13628  has label
# 13629  has label
# 13630  has label
# 13631  has label
# 13632  has label
# 13633  has label
# 13634  has label
# 13635  has label
# 13639  has label
# 13641  has label
# 13642  has label
# 13643  has label
# 13644  has label
# 13645  has label
# 13646  has label
# 13647  has label
# 13648  has label
# 13649  has label
# 13650  has label
# 13651  has label
# 13652  has label
# 13653  has label
# 13654  has label
# 13656  has label
# 13659  has label
# 13660  has label
# 13661  has label
# 13662  has label
# 13671  has label
# 13686  has label
# 13687  has label
# 13688  has label
# 13694  has label
# 13695  has label
# 13696  has label
# 13721  has label
# 13729  has label
# 13782  has label
# 13783  has label
# 13784  has label
# 13787  has label
# 13788  has label
# 13789  has label
# 13790  has label
# 13792  has label
# 13793  has label
# 13794  has label
# 13795  has label
# 13796  has label
# 13797  has label
# 13801  has label
# 13802  has label
# 13803  has label
# 13805  has label
# 13806  has label
# 13807  has label
# 13808  has label
# 13809  has label
# 13810  has label
# 13811  has label
# 13812  has label
# 13813  has label
# 13814  has label
# 13815  has label
# 13816  has label
# 13818  has label
# 13819  has label
# 13824  has label
# 13825  has label
# 13828  has label
# 13834  has label
# 13857  has label
# 13858  has label
# 13883  has label
# 13884  has label
# 13891  has label
# 13892  has label
# 13911  has label
# 13945  has label
# 13949  has label
# 13950  has label
# 13951  has label
# 13952  has label
# 13955  has label
# 13956  has label
# 13957  has label
# 13958  has label
# 13965  has label
# 13967  has label
# 13968  has label
# 13969  has label
# 13970  has label
# 13971  has label
# 13972  has label
# 13973  has label
# 13974  has label
# 13975  has label
# 13976  has label
# 13977  has label
# 13980  has label
# 13981  has label
# 13984  has label
# 13985  has label
# 13986  has label
# 14010  has label
# 14047  has label
# 14054  has label
# 14073  has label
# 14074  has label
# 14075  has label
# 14112  has label
# 14113  has label
# 14117  has label
# 14118  has label
# 14122  has label
# 14129  has label
# 14131  has label
# 14133  has label
# 14134  has label
# 14135  has label
# 14139  has label
# 14142  has label
# 14143  has label
# 14144  has label
# 14146  has label
# 14147  has label
# 14148  has label
# 14172  has label
# 14175  has label
# 14223  has label
# 14224  has label
# 14267  has label
# 14276  has label
# 14277  has label
# 14278  has label
# 14280  has label
# 14281  has label
# 14282  has label
# 14283  has label
# 14284  has label
# 14292  has label
# 14296  has label
# 14297  has label
# 14303  has label
# 14305  has label
# 14306  has label
# 14307  has label
# 14310  has label
# 14311  has label
# 14327  has label
# 14334  has label
# 14337  has label
# 14385  has label
# 14386  has label
# 14429  has label
# 14430  has label
# 14431  has label
# 14433  has label
# 14444  has label
# 14445  has label
# 14446  has label
# 14455  has label
# 14466  has label
# 14467  has label
# 14468  has label
# 14469  has label
# 14470  has label
# 14484  has label
# 14485  has label
# 14505  has label
# 14593  has label
# 14594  has label
# 14595  has label
# 14596  has label
# 14607  has label
# 14608  has label
# 14609  has label
# 14627  has label
# 14628  has label
# 14629  has label
# 14630  has label
# 14631  has label
# 14632  has label
# 14633  has label
# 14636  has label
# 14646  has label
# 14656  has label
# 14657  has label
# 14666  has label
# 14667  has label
# 14668  has label
# 14755  has label
# 14756  has label
# 14757  has label
# 14769  has label
# 14770  has label
# 14785  has label
# 14786  has label
# 14787  has label
# 14789  has label
# 14790  has label
# 14791  has label
# 14792  has label
# 14793  has label
# 14794  has label
# 14798  has label
# 14808  has label
# 14818  has label
# 14819  has label
# 14823  has label
# 14824  has label
# 14827  has label
# 14828  has label
# 14829  has label
# 14830  has label
# 14832  has label
# 14947  has label
# 14948  has label
# 14949  has label
# 14950  has label
# 14951  has label
# 14952  has label
# 14953  has label
# 14954  has label
# 14955  has label
# 14956  has label
# 14960  has label
# 14969  has label
# 14970  has label
# 14976  has label
# 14984  has label
# 14985  has label
# 14986  has label
# 14989  has label
# 14990  has label
# 14991  has label
# 14994  has label
# 15074  has label
# 15075  has label
# 15076  has label
# 15089  has label
# 15111  has label
# 15113  has label
# 15114  has label
# 15115  has label
# 15116  has label
# 15117  has label
# 15119  has label
# 15122  has label
# 15123  has label
# 15130  has label
# 15132  has label
# 15133  has label
# 15137  has label
# 15138  has label
# 15139  has label
# 15148  has label
# 15235  has label
# 15236  has label
# 15237  has label
# 15250  has label
# 15251  has label
# 15252  has label
# 15255  has label
# 15272  has label
# 15273  has label
# 15275  has label
# 15276  has label
# 15277  has label
# 15278  has label
# 15280  has label
# 15281  has label
# 15282  has label
# 15283  has label
# 15284  has label
# 15285  has label
# 15286  has label
# 15288  has label
# 15289  has label
# 15290  has label
# 15291  has label
# 15292  has label
# 15293  has label
# 15295  has label
# 15300  has label
# 15301  has label
# 15312  has label
# 15398  has label
# 15410  has label
# 15411  has label
# 15412  has label
# 15413  has label
# 15414  has label
# 15416  has label
# 15433  has label
# 15434  has label
# 15435  has label
# 15436  has label
# 15439  has label
# 15440  has label
# 15441  has label
# 15442  has label
# 15443  has label
# 15444  has label
# 15445  has label
# 15446  has label
# 15447  has label
# 15448  has label
# 15449  has label
# 15450  has label
# 15451  has label
# 15452  has label
# 15453  has label
# 15454  has label
# 15455  has label
# 15462  has label
# 15463  has label
# 15572  has label
# 15573  has label
# 15574  has label
# 15575  has label
# 15576  has label
# 15578  has label
# 15596  has label
# 15597  has label
# 15598  has label
# 15601  has label
# 15602  has label
# 15603  has label
# 15604  has label
# 15605  has label
# 15606  has label
# 15608  has label
# 15609  has label
# 15610  has label
# 15611  has label
# 15612  has label
# 15613  has label
# 15614  has label
# 15615  has label
# 15616  has label
# 15617  has label
# 15618  has label
# 15723  has label
# 15724  has label
# 15725  has label
# 15734  has label
# 15735  has label
# 15736  has label
# 15737  has label
# 15738  has label
# 15739  has label
# 15758  has label
# 15759  has label
# 15761  has label
# 15762  has label
# 15763  has label
# 15764  has label
# 15767  has label
# 15768  has label
# 15769  has label
# 15770  has label
# 15771  has label
# 15772  has label
# 15773  has label
# 15774  has label
# 15775  has label
# 15776  has label
# 15777  has label
# 15778  has label
# 15779  has label
# 15780  has label
# 15783  has label
# 15812  has label
# 15814  has label
# 15815  has label
# 15821  has label
# 15822  has label
# 15885  has label
# 15886  has label
# 15888  has label
# 15896  has label
# 15897  has label
# 15920  has label
# 15924  has label
# 15926  has label
# 15927  has label
# 15928  has label
# 15929  has label
# 15930  has label
# 15931  has label
# 15932  has label
# 15933  has label
# 15934  has label
# 15935  has label
# 15936  has label
# 15937  has label
# 15938  has label
# 15939  has label
# 15940  has label
# 15941  has label
# 15942  has label
# 15943  has label
# 15944  has label
# 15974  has label
# 15984  has label
# 16048  has label
# 16049  has label
# 16050  has label
# 16051  has label
# 16054  has label
# 16055  has label
# 16058  has label
# 16059  has label
# 16060  has label
# 16061  has label
# 16062  has label
# 16086  has label
# 16087  has label
# 16088  has label
# 16090  has label
# 16091  has label
# 16092  has label
# 16098  has label
# 16099  has label
# 16100  has label
# 16101  has label
# 16102  has label
# 16103  has label
# 16104  has label
# 16106  has label
# 16107  has label
# 16146  has label
# 16147  has label
# 16161  has label
# 16169  has label
# 16210  has label
# 16217  has label
# 16220  has label
# 16221  has label
# 16222  has label
# 16223  has label
# 16224  has label
# 16225  has label
# 16248  has label
# 16249  has label
# 16250  has label
# 16251  has label
# 16252  has label
# 16253  has label
# 16254  has label
# 16260  has label
# 16261  has label
# 16262  has label
# 16263  has label
# 16265  has label
# 16266  has label
# 16267  has label
# 16268  has label
# 16308  has label
# 16309  has label
# 16322  has label
# 16333  has label
# 16374  has label
# 16381  has label
# 16383  has label
# 16384  has label
# 16385  has label
# 16386  has label
# 16410  has label
# 16411  has label
# 16412  has label
# 16415  has label
# 16416  has label
# 16423  has label
# 16424  has label
# 16425  has label
# 16426  has label
# 16429  has label
# 16430  has label
# 16470  has label
# 16471  has label
# 16472  has label
# 16484  has label
# 16486  has label
# 16495  has label
# 16496  has label
# 16543  has label
# 16544  has label
# 16545  has label
# 16547  has label
# 16548  has label
# 16558  has label
# 16559  has label
# 16573  has label
# 16574  has label
# 16575  has label
# 16576  has label
# 16577  has label
# 16578  has label
# 16583  has label
# 16588  has label
# 16589  has label
# 16590  has label
# 16591  has label
# 16597  has label
# 16651  has label
# 16652  has label
# 16657  has label
# 16658  has label
# 16709  has label
# 16710  has label
# 16711  has label
# 16712  has label
# 16720  has label
# 16721  has label
# 16735  has label
# 16736  has label
# 16737  has label
# 16738  has label
# 16739  has label
# 16745  has label
# 16748  has label
# 16749  has label
# 16751  has label
# 16752  has label
# 16753  has label
# 16758  has label
# 16759  has label
# 16760  has label
# 16761  has label
# 16762  has label
# 16763  has label
# 16814  has label
# 16819  has label
# 16820  has label
# 16872  has label
# 16873  has label
# 16874  has label
# 16875  has label
# 16897  has label
# 16898  has label
# 16911  has label
# 16913  has label
# 16914  has label
# 16915  has label
# 16916  has label
# 16917  has label
# 16918  has label
# 16920  has label
# 16921  has label
# 16922  has label
# 16923  has label
# 16925  has label
# 16926  has label
# 17034  has label
# 17036  has label
# 17037  has label
# 17038  has label
# 17046  has label
# 17047  has label
# 17050  has label
# 17059  has label
# 17060  has label
# 17061  has label
# 17078  has label
# 17079  has label
# 17082  has label
# 17083  has label
# 17084  has label
# 17085  has label
# 17087  has label
# 17088  has label
# 17089  has label
# 17146  has label
# 17196  has label
# 17197  has label
# 17198  has label
# 17199  has label
# 17201  has label
# 17208  has label
# 17209  has label
# 17211  has label
# 17212  has label
# 17221  has label
# 17222  has label
# 17223  has label
# 17243  has label
# 17244  has label
# 17245  has label
# 17246  has label
# 17247  has label
# 17249  has label
# 17308  has label
# 17356  has label
# 17357  has label
# 17358  has label
# 17359  has label
# 17360  has label
# 17361  has label
# 17362  has label
# 17363  has label
# 17368  has label
# 17369  has label
# 17370  has label
# 17372  has label
# 17373  has label
# 17406  has label
# 17407  has label
# 17471  has label
# 17472  has label
# 17518  has label
# 17519  has label
# 17520  has label
# 17521  has label
# 17522  has label
# 17523  has label
# 17524  has label
# 17525  has label
# 17531  has label
# 17533  has label
# 17535  has label
# 17568  has label
# 17569  has label
# 17612  has label
# 17633  has label
# 17634  has label
# 17681  has label
# 17682  has label
# 17683  has label
# 17684  has label
# 17685  has label
# 17686  has label
# 17691  has label
# 17693  has label
# 17694  has label
# 17695  has label
# 17697  has label
# 17773  has label
# 17774  has label
# 17775  has label
# 17790  has label
# 17842  has label
# 17843  has label
# 17845  has label
# 17846  has label
# 17847  has label
# 17848  has label
# 17869  has label
# 17936  has label
# 17937  has label
# 17952  has label
# 18005  has label
# 18007  has label
# 18100  has label
# 18101  has label
# 18263  has label
# 18264  has label
# 18377  has label
# 18398  has label
# 18399  has label
# 18400  has label
# 18401  has label
# 18539  has label
# 18540  has label
# 18560  has label
# 18561  has label
# 18562  has label
# 18701  has label
# 18702  has label
# 18721  has label
# 18722  has label
# 18723  has label
# 18752  has label
# 18830  has label
# 18884  has label
# 18886  has label
# 18915  has label
# 18917  has label
# 18918  has label
# 18924  has label
# 18931  has label
# 19205  has label
# 19312  has label
# 19313  has label
# 19314  has label
# 19369  has label
# 19402  has label
# 19403  has label
# 19473  has label
# 19474  has label
# 19475  has label
# 19563  has label
# 19564  has label
# 19632  has label
# 19634  has label
# 19635  has label
# 19636  has label
# 19637  has label
# 19638  has label
# 19639  has label
# 19713  has label
# 19714  has label
# 19715  has label
# 19726  has label
# 19741  has label
# 19742  has label
# 19743  has label
# 19744  has label
# 19794  has label
# 19795  has label
# 19796  has label
# 19797  has label
# 19798  has label
# 19799  has label
# 19800  has label
# 19801  has label
# 19874  has label
# 19875  has label
# 19876  has label
# 19877  has label
# 19887  has label
# 19896  has label
# 19902  has label
# 19903  has label
# 19904  has label
# 19957  has label
# 19958  has label
# 19959  has label
# 19960  has label
# 19961  has label
# 19962  has label
# 19963  has label
# 20036  has label
# 20037  has label
# 20038  has label
# 20039  has label
# 20058  has label
# 20064  has label
# 20118  has label
# 20119  has label
# 20120  has label
# 20121  has label
# 20122  has label
# 20123  has label
# 20199  has label
# 20226  has label
# 20232  has label
# 20233  has label
# 20281  has label
# 20282  has label
# 20283  has label
# 20285  has label
# 20392  has label
# 20393  has label
# 20394  has label
# 20395  has label
# 20445  has label
# 20549  has label
# 20550  has label
# 20554  has label
# 20555  has label
# 20659  has label
# 20692  has label
# 20712  has label
# 20714  has label
# 20716  has label
# 20717  has label
# 20718  has label
# 20765  has label
# 20766  has label
# 20845  has label
# 20846  has label
# 20852  has label
# 20853  has label
# 20854  has label
# 20876  has label
# 20877  has label
# 20878  has label
# 20879  has label
# 20880  has label
# 21008  has label
# 21013  has label
# 21014  has label
# 21023  has label
# 21038  has label
# 21039  has label
# 21040  has label
# 21041  has label
# 21042  has label
# 21141  has label
# 21142  has label
# 21143  has label
# 21144  has label
# 21145  has label
# 21177  has label
# 21182  has label
# 21185  has label
# 21186  has label
# 21202  has label
# 21246  has label
# 21304  has label
# 21305  has label
# 21339  has label
# 21340  has label
# 21341  has label
# 21342  has label
# 21345  has label
# 21347  has label
# 21348  has label
# 21364  has label
# 21436  has label
# 21465  has label
# 21472  has label
# 21505  has label
# 21506  has label
# 21507  has label
# 21598  has label
# 21599  has label
# 21666  has label
# 21667  has label
# 21668  has label
# 21669  has label
# 21672  has label
# 21759  has label
# 21760  has label
# 21763  has label
# 21814  has label
# 21828  has label
# 21829  has label
# 21830  has label
# 21831  has label
# 21833  has label
# 21834  has label
# 21912  has label
# 21913  has label
# 21920  has label
# 21921  has label
# 21922  has label
# 21925  has label
# 21943  has label
# 21976  has label
# 21977  has label
# 21994  has label
# 21995  has label
# 22074  has label
# 22075  has label
# 22083  has label
# 22084  has label
# 22105  has label
# 22106  has label
# 22137  has label
# 22138  has label
# 22154  has label
# 22155  has label
# 22156  has label
# 22157  has label
# 22232  has label
# 22233  has label
# 22234  has label
# 22235  has label
# 22268  has label
# 22299  has label
# 22316  has label
# 22317  has label
# 22318  has label
# 22319  has label
# 22394  has label
# 22395  has label
# 22468  has label
# 22478  has label
# 22479  has label
# 22720  has label
# 22728  has label
# 22880  has label
# 22881  has label
# 22882  has label
# 22884  has label
# 22890  has label
# 22963  has label
# 22964  has label
# 23073  has label
# 23094  has label
# 23116  has label
# 23117  has label
# 23201  has label
# 23202  has label
# 23207  has label
# 23222  has label
# 23235  has label
# 23256  has label
# 23257  has label
# 23364  has label
# 23365  has label
# 23384  has label
# 23397  has label
# 23398  has label
# 23416  has label
# 23417  has label
# 23418  has label
# 23527  has label
# 23546  has label
# 23557  has label
# 23558  has label
# 23559  has label
# 23560  has label
# 23561  has label
# 23580  has label
# 23599  has label
# 23688  has label
# 23689  has label
# 23719  has label
# 23720  has label
# 23721  has label
# 23723  has label
# 23760  has label
# 23761  has label
# 23762  has label
# 23842  has label
# 23851  has label
# 23881  has label
# 23882  has label
# 23883  has label
# 23924  has label
# 23925  has label
# 24010  has label
# 24039  has label
# 24040  has label
# 24041  has label
# 24042  has label
# 24047  has label
# 24086  has label
# 24087  has label
# 24201  has label
# 24202  has label
# 24203  has label
# 24204  has label
# 24248  has label
# 24249  has label
# 24364  has label
# 24366  has label
# 24374  has label
# 24526  has label
# 24537  has label
# 25133  has label
# 25147  has label
# 25221  has label
# 25292  has label
# 25295  has label
# 25309  has label
# 25383  has label
# 25454  has label
# 25544  has label
# 25545  has label
# 25616  has label
# 25637  has label
# 25801  has label
# 25855  has label
# 25857  has label
# 25858  has label
# 25933  has label
# 25937  has label
# 26018  has label
# 26019  has label
# 26020  has label
# 26182  has label
# 26258  has label
# 26259  has label
# 26419  has label
# 26449  has label
# 26580  has label
# 26581  has label
# 26591  has label
# 26610  has label
# 26611  has label
# 26613  has label
# 26749  has label
# 26750  has label
# 26772  has label
# 26779  has label
# 26798  has label
# 26911  has label
# 26912  has label
# 26934  has label
# 26941  has label
# 26953  has label
# 26954  has label
# 27114  has label
# 27115  has label
# 27167  has label
# 27168  has label
# 27169  has label
# 27331  has label
# 27436  has label
# 27475  has label
# 27489  has label
# 27492  has label
# 27493  has label
# 27580  has label
# 27581  has label
# 27598  has label
# 27599  has label
# 27637  has label
# 27742  has label
# 27743  has label
# 27940  has label
# 27941  has label
# 27973  has label
# 27974  has label
# 27978  has label
# 27979  has label
# 28066  has label
# 28083  has label
# 28084  has label
# 28102  has label
# 28103  has label
# 28228  has label
# 28229  has label
# 28264  has label
# 28302  has label
# 28462  has label
# 28463  has label
# 28535  has label
# 28570  has label
# 28571  has label
# 28613  has label
# 28614  has label
# 28726  has label
# 28732  has label
# 28894  has label
# 28917  has label
# 28947  has label
# 29079  has label
# 29100  has label
# 29266  has label
# 29354  has label
# 29355  has label
# 29356  has label
# 29366  has label
# 29435  has label
# 29516  has label
# 29517  has label
# 29518  has label
# 29519  has label
# 29591  has label
# 29592  has label
# 29678  has label
# 29679  has label
# 29753  has label
# 29754  has label
# 29760  has label
# 29994  has label
# 29995  has label
# 30094  has label
# 30095  has label
# 30227  has label
# 30421  has label
# 30422  has label
# 30578  has label
# 30579  has label
# 30580  has label
# 30740  has label
# 31034  has label
# 31035  has label
# 31196  has label
# 31197  has label
# 31202  has label
# 31369  has label
# 31393  has label
# 31394  has label
# 31531  has label
# 31693  has label
# 31694  has label
# 31723  has label
# 31724  has label
# 31855  has label
# 31856  has label
# 31988  has label
# 31989  has label
# 31993  has label
# 32016  has label
# 32017  has label
# 32018  has label
# 32048  has label
# 32151  has label
# 32178  has label
# 32179  has label
# 32312  has label
# 32313  has label
# 32340  has label
# 32341  has label
# 32344  has label
# 32475  has label
# 32476  has label
# 32489  has label
# 32490  has label
# 32503  has label
# 32638  has label
# 32651  has label
# 32652  has label
# 32658  has label
# 32659  has label
# 32665  has label
# 32799  has label
# 32800  has label
# 32813  has label
# 32961  has label
# 32962  has label
# 33146  has label
# 33148  has label
# 33149  has label
# 33307  has label
# 33308  has label
# 33310  has label
# 33311  has label
# 33471  has label
# 33472  has label
# 33627  has label
# Done
# Images with no labels:  33041 , Images with labels:  2113
